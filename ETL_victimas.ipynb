# %%
import pandas as pd

# %%
#Se carga el dataset de homicidios_victimas
df_homicidios_victimas=pd.read_excel('raw_data\homicidios.xlsx', sheet_name='VICTIMAS', engine='openpyxl')
df_homicidios_victimas.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %% [markdown]
# Normalizacion en nombres de columnas

# %%
#Se pasan a minusculas los nombres de las columnas
df_homicidios_victimas.columns = df_homicidios_victimas.columns.str.lower()
df_homicidios_victimas.head()
# Out:
#     id_hecho      fecha  aaaa  mm  dd        rol victima       sexo edad  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    fecha_fallecimiento
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %%
#Se elimina la columna fecha_fallecimiento ya que no es relevante en nuestro analisis
df_homicidios_victimas.drop(columns='fecha_fallecimiento', inplace=True)

# %% [markdown]
# Tratamiento de valores faltantes y duplicados

# %%
#Se identifiacn valores faltantes por columna
df_homicidios_victimas.isnull().sum()
# Out:
# id_hecho    0
# fecha       0
# aaaa        0
# mm          0
# dd          0
# rol         0
# victima     0
# sexo        0
# edad        0
# dtype: int64

# %%
#Se verifica la existencia de registros duplicados
df_homicidios_victimas[df_homicidios_victimas.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_hecho, fecha, aaaa, mm, dd, rol, victima, sexo, edad]
# Index: []

# %% [markdown]
# Se guarda el dataset limpio en formato csv

# %%
df_homicidios_victimas[df_homicidios_victimas['sexo']=='FEMENINO']
# Out:
#       id_hecho      fecha  aaaa  mm  dd                   rol victima  \
# 10   2016-0015 2016-02-14  2016   2  14                PEATON  PEATON
# 11   2016-0016 2016-02-14  2016   2  14  PASAJERO_ACOMPAÑANTE    MOTO
# 13   2016-0019 2016-02-17  2016   2  17                PEATON  PEATON
# 31   2016-0043 2016-03-30  2016   3  30                PEATON  PEATON
# 35   2016-0048 2016-04-15  2016   4  15                PEATON  PEATON
# ..         ...        ...   ...  ..  ..                   ...     ...
# 696  2021-0077 2021-10-18  2021  10  18             CONDUCTOR    MOTO
# 707  2021-0087 2021-11-27  2021  11  27                PEATON  PEATON
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
#
#          sexo edad
# 10   FEMENINO   16
# 11   FEMENINO   19
# 13   FEMENINO   65
# 31   FEMENINO   56
# 35   FEMENINO   SD
# ...

# %%
df_homicidios_victimas.to_csv('processed_data/homicidios_victimas.csv', index=False)
